# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
"""Visualize Training"""
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['acc'], color='b', label="Training accuracy")
ax2.plot(history.history['val_acc'], color='r',
            label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
# log=pd.read_csv("./log/training.log.fn.tn.csv")
log=pd.read_csv("./log/training.log.csv")
ALPHA=0.99
print("ALPHA是正样本上的权重，即bad_1.")
print(f"ALPHA设置为: {ALPHA}.")
# Out:
# ALPHA是正样本上的权重，即bad_1.
# ALPHA设置为: 0.99.

# %%
mpl.rcParams['figure.figsize'] = (8, 5)
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')

# epoch,
# accuracy,
# auc_bad_1,
# false_negatives,
# false_negatives_1,
# loss
# true_negatives,
# true_negatives_1,
# val_accuracy,
# val_auc_bad_1,
# val_false_negatives,
# val_false_negatives_1,
# val_loss,
# val_true_negatives,
# val_true_negatives_1

# %% [markdown]
# ## 结果
# 忘了log false_positives 和 true_positives

# %%
plt.plot(log["epoch"].values, log["loss"].values, color=cycle[0], marker='o', linewidth=0.5, markersize=2, label="loss")
plt.legend()
plt.tight_layout()
plt.grid()

# %% [markdown]
# 曲线中可以看出来 ResNet 的作用。在 epoch=80 处后，AUC被更好的优化了。

# %%
plt.plot(log["epoch"].values, log["auc_bad_1"].values, color=cycle[3], marker='o', linewidth=0.5, markersize=2, label="auc_bad_1")
plt.plot(log["epoch"].values, log["val_auc_bad_1"].values, color=cycle[8], marker='o', linewidth=0.5, markersize=2, label="val_auc_bad_1")
plt.ylim(0.9,1) # should supervise AUC
plt.legend()
plt.tight_layout()
plt.grid()

# %% [markdown]
# Train AUC 要优化到 0.997

# %%
plt.plot(log["epoch"].values, log["auc_bad_1"].values, color=cycle[3], marker='o', linewidth=0.5, markersize=2, label="auc_bad_1")
plt.ylim(0.97,1) # should supervise AUC
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["val_auc_bad_1"].values, color=cycle[4], marker='o', linewidth=0.5, markersize=2, label="val_auc_bad_1")
plt.ylim(0.97,1) # should supervise AUC
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["fp"].values, color=cycle[0], marker='*', linewidth=0.5, markersize=2, label="fp")
plt.plot(log["epoch"].values, log["tp"].values, color=cycle[1], marker='*', linewidth=0.5, markersize=2, label="tp")
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["fn"].values, color=cycle[0], marker='*', linewidth=0.5, markersize=2, label="fn")
plt.plot(log["epoch"].values, log["tn"].values, color=cycle[1], marker='*', linewidth=0.5, markersize=2, label="tn")
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["fn"].values, color=cycle[0], marker='*', linewidth=0.5, markersize=2, label="fn")
plt.plot(log["epoch"].values, log["fp"].values, color=cycle[1], marker='*', linewidth=0.5, markersize=2, label="fp")
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["val_fn"].values, color=cycle[0], marker='*', linewidth=0.5, markersize=2, label="val_fn")
plt.plot(log["epoch"].values, log["val_fp"].values, color=cycle[1], marker='*', linewidth=0.5, markersize=2, label="val_fp")
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["val_fp"].values, color=cycle[0], marker='*', linewidth=0.5, markersize=2, label="val_fp")
plt.plot(log["epoch"].values, log["val_tp"].values, color=cycle[3], marker='*', linewidth=0.5, markersize=2, label="val_tp")
plt.legend()
plt.tight_layout()
plt.grid()

# %%
print("fp_tp_rate 越小越好")
# tp是统计的tp样本的数量
# 如果把tp视作0.99，or约等于1，
plt.plot(log["epoch"].values, log["val_fp"]/log["val_tp"].values, color=cycle[3], marker='*', linewidth=0.5, markersize=2, label="fp_tp_rate")
plt.legend()
plt.tight_layout()
plt.grid()
# Out:
# fp_tp_rate 越小越好
